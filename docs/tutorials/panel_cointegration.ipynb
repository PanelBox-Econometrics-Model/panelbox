# %% [markdown]
# # Panel Cointegration Tests Tutorial
#
# Complete guide to panel cointegration testing in PanelBox.

# %%
import numpy as np
import pandas as pd
from panelbox.diagnostics.cointegration import westerlund_test, pedroni_test, kao_test
np.random.seed(42)
