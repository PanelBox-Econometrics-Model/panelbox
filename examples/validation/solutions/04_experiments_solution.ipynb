# %% [markdown]
# # Experiments and Model Comparison — SOLUTION
#
# **This is the worked solution notebook.**
# It mirrors `04_experiments_model_comparison.ipynb` and fills in all `raise NotImplementedError` cells.
#
# > Instructors: do not distribute this file to students before they complete the tutorial notebook.

# %%
import sys, pathlib
ROOT = pathlib.Path('..').resolve()
PANELBOX_ROOT = pathlib.Path('../../..')
for p in [str(ROOT), str(PANELBOX_ROOT)]:
    if p not in sys.path:
        sys.path.insert(0, p)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
print("Solution notebook loaded — fill in implementation below")

# %% [markdown]
# ## Solution cells
#
# Each section below corresponds to a numbered section in the tutorial notebook.
# Expand and implement each cell with the complete working solution.
